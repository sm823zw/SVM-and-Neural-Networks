# %%
import numpy as np
import seaborn as sns
import tensorflow as tf
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
path_train_data = "R:/IISc/Sem 2/PRNN/Assignments/assignment-3-files/MNIST/mnist-rot_training_data.mat"
path_train_label = "R:/IISc/Sem 2/PRNN/Assignments/assignment-3-files/MNIST/mnist-rot_training_label.mat"
path_test_data = "R:/IISc/Sem 2/PRNN/Assignments/assignment-3-files/MNIST/mnist-rot_test_data.mat"
path_test_label = "R:/IISc/Sem 2/PRNN/Assignments/assignment-3-files/MNIST/mnist-rot_test_label.mat"

# %%
train_data_mat = loadmat(path_train_data)
train_data = train_data_mat['train_data']

train_label_mat = loadmat(path_train_label)
train_label = train_label_mat['train_label']

test_data_mat = loadmat(path_test_data)
test_data = test_data_mat['test_data']

test_label_mat = loadmat(path_test_label)
test_label = test_label_mat['test_label']

# %%
plt.imshow(train_data[0], cmap='gray')

# %%
train_data = train_data.reshape(train_data.shape[0], 784)
test_data = test_data.reshape(test_data.shape[0], 784)
train_label = train_label.T
test_label = test_label.T

# %%
train_label.shape
# Out:
# (12000, 1)

# %%
train_data.shape
# Out:
# (12000, 784)

# %%
# from sklearn.model_selection import train_test_split
# train_data, _, train_label, _ = train_test_split(train_data, train_label, test_size=0.6)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(train_data)
X_test = scaler.transform(test_data)
# X_train = X_train.reshape((X_train.shape[0], 28, 28, 1))
# X_test = X_test.reshape((X_test.shape[0], 28, 28, 1))

# %%
X_train.shape
# Out:
# (12000, 784)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
y_train = ohe.fit_transform(train_label).toarray()
y_test = ohe.fit_transform(test_label).toarray()

# %%
lam = tf.keras.regularizers.l2(l=0.05)
init = tf.initializers.he_normal()
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, input_dim=784, kernel_initializer=init, kernel_regularizer=lam),
    tf.keras.layers.LeakyReLU(0.1),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1),

    tf.keras.layers.Dense(128, kernel_initializer=init, kernel_regularizer=lam),
    tf.keras.layers.LeakyReLU(0.1),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.1),

    # tf.keras.layers.Dense(64, kernel_initializer=init, kernel_regularizer=lam),
    # tf.keras.layers.ReLU(),
    # tf.keras.layers.Dropout(0.2),

    # tf.keras.layers.Dense(32, kernel_initializer=init, kernel_regularizer=lam),
    # tf.keras.layers.ReLU(),
    # tf.keras.layers.Dropout(0.1),

    tf.keras.layers.Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 64)                50240
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 59,850
# Trainable params: 59,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
# lam = tf.keras.regularizers.l1(l=0.001)
# # lam_2 = tf.keras.regularizers.l2(l=0.01)
# init = tf.initializers.he_normal()
# model = tf.keras.models.Sequential([
#     tf.keras.layers.Conv2D(8, (3, 3), padding='same', kernel_initializer=init, input_shape=(28, 28, 1), kernel_regularizer=lam),
#     # tf.keras.layers.BatchNormalization(),
#     # tf.keras.layers.ReLU(),
#     tf.keras.layers.LeakyReLU(0.1),

#     tf.keras.layers.Conv2D(16, (3, 3), padding='same', kernel_initializer=init, kernel_regularizer=lam),
#     # tf.keras.layers.BatchNormalization(),
#     # tf.keras.layers.ReLU(),
#     tf.keras.layers.LeakyReLU(0.1),

#     tf.keras.layers.MaxPool2D((2, 2)),

#     tf.keras.layers.Conv2D(32, (3, 3), padding='same', kernel_initializer=init, kernel_regularizer=lam),
#     # tf.keras.layers.BatchNormalization(),
#     # tf.keras.layers.ReLU(),
#     tf.keras.layers.LeakyReLU(0.1),

#     tf.keras.layers.Conv2D(64, (3, 3), padding='same', kernel_initializer=init, kernel_regularizer=lam),
#     # tf.keras.layers.BatchNormalization(),
#     # tf.keras.layers.ReLU(),
#     tf.keras.layers.LeakyReLU(0.1),

#     tf.keras.layers.MaxPool2D((2, 2)),

#     tf.keras.layers.Conv2D(96, (3, 3), padding='same', kernel_initializer=init, kernel_regularizer=lam),
#     # tf.keras.layers.BatchNormalization(),
#     # tf.keras.layers.ReLU(),
#     tf.keras.layers.LeakyReLU(0.1),

#     tf.keras.layers.Conv2D(128, (3, 3), padding='same', kernel_initializer=init, kernel_regularizer=lam),
#     # tf.keras.layers.BatchNormalization(),
#     # tf.keras.layers.ReLU(),
#     tf.keras.layers.LeakyReLU(0.1),

#     tf.keras.layers.MaxPool2D((2, 2)),

#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dropout(0.2),

#     tf.keras.layers.Dense(64, kernel_initializer=init, kernel_regularizer=lam),
#     # tf.keras.layers.ReLU(),
#     tf.keras.layers.LeakyReLU(0.1),
#     tf.keras.layers.Dropout(0.2),
    
#     tf.keras.layers.Dense(10, activation='softmax', kernel_initializer=init, kernel_regularizer=lam)
# ])
# model.summary()

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(patience=5)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1)

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_valid, y_valid), shuffle=True, callbacks=[])
# Out:
# Epoch 1/100
# 96/96 [==============================] - 1s 7ms/step - loss: 18.1517 - accuracy: 0.2372 - val_loss: 9.8435 - val_accuracy: 0.4985
# Epoch 2/100
# 96/96 [==============================] - 0s 5ms/step - loss: 8.3703 - accuracy: 0.5277 - val_loss: 5.0256 - val_accuracy: 0.5575
# Epoch 3/100
# 96/96 [==============================] - 0s 5ms/step - loss: 4.4075 - accuracy: 0.5719 - val_loss: 3.0177 - val_accuracy: 0.5516
# Epoch 4/100
# 96/96 [==============================] - 0s 5ms/step - loss: 2.7556 - accuracy: 0.5722 - val_loss: 2.1759 - val_accuracy: 0.5811
# Epoch 5/100
# 96/96 [==============================] - 0s 5ms/step - loss: 2.0689 - accuracy: 0.5851 - val_loss: 1.8410 - val_accuracy: 0.5841
# Epoch 6/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.8023 - accuracy: 0.5938 - val_loss: 1.7077 - val_accuracy: 0.5959
# Epoch 7/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.6575 - accuracy: 0.5944 - val_loss: 1.6687 - val_accuracy: 0.5605
# Epoch 8/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.5766 - accuracy: 0.6243 - val_loss: 1.6309 - val_accuracy: 0.5546
# Epoch 9/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.5817 - accuracy: 0.6255 - val_loss: 1.5849 - val_accuracy: 0.6047
# Epoch 10/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.5452 - accuracy: 0.6309 - val_loss: 1.6083 - val_accuracy: 0.6224
# Epoch 11/100
# 96/96 [==============================] - 1s 7ms/step - loss: 1.5497 - accuracy: 0.6356 - val_loss: 1.5758 - val_accuracy: 0.6106
# Epoch 12/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.5286 - accuracy: 0.6188 - val_loss: 1.5607 - val_accuracy: 0.6254
# Epoch 13/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1
100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.2320 - accuracy: 0.7618 - val_loss: 1.4598 - val_accuracy: 0.6873
# Epoch 45/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.1812 - accuracy: 0.7783 - val_loss: 1.4214 - val_accuracy: 0.7050
# Epoch 46/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.2288 - accuracy: 0.7759 - val_loss: 1.4810 - val_accuracy: 0.6814
# Epoch 47/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.2064 - accuracy: 0.7848 - val_loss: 1.4346 - val_accuracy: 0.6991
# Epoch 48/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.2090 - accuracy: 0.7565 - val_loss: 1.4874 - val_accuracy: 0.6519
# Epoch 49/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1953 - accuracy: 0.7753 - val_loss: 1.4820 - val_accuracy: 0.6873
# Epoch 50/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.2235 - accuracy: 0.7668 - val_loss: 1.4328 - val_accuracy: 0.7050
# Epoch 51/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.2022 - accuracy: 0.7673 - val_loss: 1.4951 - val_accuracy: 0.6608
# Epoch 52/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.1780 - accuracy: 0.7885 - val_loss: 1.4634 - val_accuracy: 0.6903
# Epoch 53/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.2098 - accuracy: 0.7710 - val_loss: 1.4672 - val_accuracy: 0.6991
# Epoch 54/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.2038 - accuracy: 0.7765 - val_loss: 1.4952 - val_accuracy: 0.6696
# Epoch 55/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1590 - accuracy: 0.7755 - val_loss: 1.4640 - val_accuracy: 0.6991
# Epoch 56/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1482 - accuracy: 0.7909 - val_loss: 1.4460 - val_accuracy: 0.7021
# Epoch 57/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1759 - accuracy: 0.7992 - val_loss: 1.4297 - val_accuracy: 0.6873
# Epoch 58/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1316 - accuracy: 0.7944 - val_loss: 1.4113 - val_accuracy: 0.7286
# Epoch 59/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1550 - accuracy: 0.7882 - val_loss: 1.4537 - val_accuracy: 0.7286
# Epoch 60/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.2054 - accuracy: 0.7762 - val_loss: 1.4260 - val_accuracy: 0.7109
# Epoch 61/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1091 - accuracy: 0.8130 - val_loss: 1.5148 - val_accuracy: 0.6844
# Epoch 62/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1774 - accuracy: 0.7854 - val_loss: 1.4481 - val_accuracy: 0.6962
# Epoch 63/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.2091 - accuracy: 0.7688 - val_loss: 1.4555 - val_accuracy: 0.6932
# Epoch 64/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1575 - accuracy: 0.7964 - val_loss: 1.4308 - val_accuracy: 0.6903
# Epoch 65/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1375 - accuracy: 0.7975 - val_loss: 1.4976 - val_accuracy: 0.6814
# Epoch 66/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1255 - accuracy: 0.8035 - val_loss: 1.3687 - val_accuracy: 0.7316
# Epoch 67/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0996 - accuracy: 0.7958 - val_loss: 1.5064 - val_accuracy: 0.6519
# Epoch 68/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1407 - accuracy: 0.7892 - val_loss: 1.4692 - val_accuracy: 0.7139
# Epoch 69/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1529 - accuracy: 0.8052 - val_loss: 1.4422 - val_accuracy: 0.7080
# Epoch 70/100
# 96/96 [==============================] - 1s 7ms/step - loss: 1.0934 - accuracy: 0.8184 - val_loss: 1.4399 - val_accuracy: 0.6962
# Epoch 71/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1228 - accuracy: 0.8001 - val_loss: 1.5499 - val_accuracy: 0.6814
# Epoch 72/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1145 - accuracy: 0.8117 - val_loss: 1.4516 - val_accuracy: 0.6903
# Epoch 73/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0520 - accuracy: 0.8227 - val_loss: 1.3714 - val_accuracy: 0.7198
# Epoch 74/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1063 - accuracy: 0.7991 - val_loss: 1.3981 - val_accuracy: 0.7227
# Epoch 75/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0737 - accuracy: 0.8360 - val_loss: 1.4436 - val_accuracy: 0.6873
# Epoch 76/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1589 - accuracy: 0.7946 - val_loss: 1.4501 - val_accuracy: 0.7109
# Epoch 77/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1653 - accuracy: 0.7929 - val_loss: 1.4437 - val_accuracy: 0.7227
# Epoch 78/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1083 - accuracy: 0.8047 - val_loss: 1.4612 - val_accuracy: 0.6844
# Epoch 79/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.1007 - accuracy: 0.8075 - val_loss: 1.5091 - val_accuracy: 0.6873
# Epoch 80/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0839 - accuracy: 0.8220 - val_loss: 1.5011 - val_accuracy: 0.6903
# Epoch 81/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0673 - accuracy: 0.8299 - val_loss: 1.4346 - val_accuracy: 0.6844
# Epoch 82/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.0950 - accuracy: 0.8239 - val_loss: 1.5127 - val_accuracy: 0.6932
# Epoch 83/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1255 - accuracy: 0.8089 - val_loss: 1.4578 - val_accuracy: 0.6991
# Epoch 84/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0668 - accuracy: 0.8276 - val_loss: 1.4625 - val_accuracy: 0.6873
# Epoch 85/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0852 - accuracy: 0.8090 - val_loss: 1.4401 - val_accuracy: 0.7080
# Epoch 86/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0522 - accuracy: 0.8405 - val_loss: 1.4408 - val_accuracy: 0.7139
# Epoch 87/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0603 - accuracy: 0.8167 - val_loss: 1.4141 - val_accuracy: 0.7316
# Epoch 88/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0274 - accuracy: 0.8307 - val_loss: 1.5464 - val_accuracy: 0.6637
# Epoch 89/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1060 - accuracy: 0.8099 - val_loss: 1.4498 - val_accuracy: 0.6844
# Epoch 90/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0693 - accuracy: 0.8211 - val_loss: 1.4182 - val_accuracy: 0.7080
# Epoch 91/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0871 - accuracy: 0.8095 - val_loss: 1.4537 - val_accuracy: 0.6991
# Epoch 92/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1171 - accuracy: 0.8092 - val_loss: 1.5082 - val_accuracy: 0.6991
# Epoch 93/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.1396 - accuracy: 0.8079 - val_loss: 1.4800 - val_accuracy: 0.7109
# Epoch 94/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0723 - accuracy: 0.8308 - val_loss: 1.4489 - val_accuracy: 0.7139
# Epoch 95/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0455 - accuracy: 0.8284 - val_loss: 1.3613 - val_accuracy: 0.7050
# Epoch 96/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0362 - accuracy: 0.8258 - val_loss: 1.5166 - val_accuracy: 0.6578
# Epoch 97/100
# 96/96 [==============================] - 0s 4ms/step - loss: 1.0728 - accuracy: 0.8178 - val_loss: 1.4664 - val_accuracy: 0.6962
# Epoch 98/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0736 - accuracy: 0.8105 - val_loss: 1.4461 - val_accuracy: 0.7050
# Epoch 99/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0582 - accuracy: 0.8270 - val_loss: 1.4031 - val_accuracy: 0.7139
# Epoch 100/100
# 96/96 [==============================] - 0s 5ms/step - loss: 1.0561 - accuracy: 0.8261 - val_loss: 1.4996 - val_accuracy: 0.6962

# %%
y_pred = model.predict(X_test)
#Converting predictions to label
pred = list()
for i in range(len(y_pred)):
    pred.append(np.argmax(y_pred[i]))
#Converting one hot encoded test label to label
test = list()
for i in range(len(y_test)):
    test.append(np.argmax(y_test[i]))

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
a = accuracy_score(pred,test)
print('Accuracy is:', a*100)
# Out:
# Accuracy is: 67.85

# %%
sns.heatmap(confusion_matrix(pred, test), annot=True, fmt='g', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# plt.xticks([i for i in range(25)])
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.xticks([i for i in range(25)])
plt.legend(['train', 'val'], loc='upper left')
plt.show()
