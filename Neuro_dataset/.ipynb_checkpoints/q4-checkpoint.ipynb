# %%
import os
import numpy as np
import seaborn as sns
import tensorflow as tf
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
path = '../Neuro_dataset/'
path_alz = path + os.listdir(path)[0]
path_nor = path + os.listdir(path)[1]

# %%
files_alz = os.listdir(path_alz)
files_nor = os.listdir(path_nor)
d = loadmat(path_alz + '/' + files_alz[0])
d['tc_rest_aal'] = d['tc_rest_aal'].reshape((1, 140, 116))
d['tc_rest_power'] = d['tc_rest_power'].reshape((1, 140, 264))
X_aal = d['tc_rest_aal']
X_pow = d['tc_rest_power']

for i in range(1, len(files_alz)):
    d = loadmat(path_alz + '/' + files_alz[i])
    d['tc_rest_aal'] = d['tc_rest_aal'].reshape((1, 140, 116))
    d['tc_rest_power'] = d['tc_rest_power'].reshape((1, 140, 264))
    X_aal = np.vstack([X_aal, d['tc_rest_aal']])
    X_pow = np.vstack([X_pow, d['tc_rest_power']])

for i in range(len(files_nor)):
    d = loadmat(path_nor + '/' + files_nor[i])
    d['tc_rest_aal'] = d['tc_rest_aal'].reshape((1, 140, 116))
    d['tc_rest_power'] = d['tc_rest_power'].reshape((1, 140, 264))
    X_aal = np.vstack([X_aal, d['tc_rest_aal']])
    X_pow = np.vstack([X_pow, d['tc_rest_power']])

# %%
X_aal.shape
# Out:
# (81, 140, 116)

# %%
X_pow.shape
# Out:
# (81, 140, 264)

# %%
y = [1 for i in range(34)]
y.extend([0 for i in range(47)])
y = np.array(y).reshape((81, 1))
y.shape
# Out:
# (81, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_aal, y, test_size = 0.3)
a = X_train.shape[1]
b = X_train.shape[2]
print(X_train.shape, X_test.shape)
# Out:
# (56, 140, 116) (25, 140, 116)

# %%
X_train = (X_train - X_train.mean(axis=0))/X_train.std(axis=0)
X_test = (X_test - X_train.mean(axis=0))/X_train.std(axis=0)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], X_train.shape[2], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], X_test.shape[2], 1))
print(X_train.shape, X_test.shape)
# Out:
# (56, 140, 116, 1) (25, 140, 116, 1)

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split=0.0)

# %%
datagen.fit(X_train)

# %%
lam = tf.keras.regularizers.l1(l=0)
# lam_2 = tf.keras.regularizers.l2(l=0.01)
init = tf.initializers.he_normal()
model = tf.keras.models.Sequential([

    tf.keras.layers.Conv2D(8, (7, 7), padding='same', kernel_initializer=init, input_shape=(a, b, 1), kernel_regularizer=lam),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),

    # tf.keras.layers.Conv2D(16, (5, 5), padding='same', kernel_initializer=init, kernel_regularizer=lam),
    # tf.keras.layers.BatchNormalization(),
    # tf.keras.layers.ReLU(),

    tf.keras.layers.MaxPool2D((2, 2)),

    tf.keras.layers.Conv2D(16, (7, 7), padding='same', kernel_initializer=init, kernel_regularizer=lam),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),

    tf.keras.layers.MaxPool2D((2, 2)),

    tf.keras.layers.Conv2D(32, (7, 7), padding='same', kernel_initializer=init, kernel_regularizer=lam),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),

    tf.keras.layers.MaxPool2D((2, 2)),

    tf.keras.layers.Conv2D(64, (7, 7), padding='valid', kernel_initializer=init, kernel_regularizer=lam),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),

    tf.keras.layers.MaxPool2D((2, 2)),

    tf.keras.layers.Conv2D(128, (7, 7), padding='same', kernel_initializer=init, kernel_regularizer=lam),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),

    tf.keras.layers.MaxPool2D((2, 2)),

    tf.keras.layers.Flatten(),
    # tf.keras.layers.Dropout(0.2),

    # tf.keras.layers.Dense(128, kernel_initializer=init, kernel_regularizer=lam),
    # tf.keras.layers.ReLU(),
    # tf.keras.layers.Dropout(0.2),

    tf.keras.layers.Dense(16, kernel_initializer=init, kernel_regularizer=lam),
    tf.keras.layers.ReLU(),
    # tf.keras.layers.LeakyReLU(0.1),
    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Dense(1, activation='sigmoid', kernel_initializer=init, kernel_regularizer=lam)
])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 140, 116, 8)       400
# _________________________________________________________________
# re_lu_30 (ReLU)              (None, 140, 116, 8)       0
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 70, 58, 8)         0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 70, 58, 16)        6288
# _________________________________________________________________
# re_lu_31 (ReLU)              (None, 70, 58, 16)        0
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 35, 29, 16)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 35, 29, 32)        25120
# _________________________________________________________________
# re_lu_32 (ReLU)              (None, 35, 29, 32)        0
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 17, 14, 32)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 11, 8, 64)         100416
# _________________________________________________________________
# re_lu_33 (ReLU)              (None, 11, 8, 64)         0
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 5, 4, 64)          0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 5, 4, 128)         401536
# _________________________________________________________________
# re_lu_34 (ReLU)              (None, 5, 4, 128)         0
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                8208
# _________________________________________________________________
# re_lu_35 (ReLU)              (None, 16)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 541,985
# Trainable params: 541,985
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1)

# %%
# history = model.fit(X_train, y_train, epochs=100, batch_size=8, validation_data=(X_test, y_test))

# %%
history = model.fit(datagen.flow(X_train, y_train, batch_size=8), epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 86ms/step - loss: 2.1347 - accuracy: 0.5090 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 2/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6959 - accuracy: 0.6369 - val_loss: 0.6680 - val_accuracy: 0.6000
# Epoch 3/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6944 - accuracy: 0.4670 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 4/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6924 - accuracy: 0.6257 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 5/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.6917 - accuracy: 0.6596 - val_loss: 0.6929 - val_accuracy: 0.5200
# Epoch 6/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.6931 - accuracy: 0.5010 - val_loss: 0.6929 - val_accuracy: 0.5200
# Epoch 7/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6911 - accuracy: 0.6442 - val_loss: 0.6928 - val_accuracy: 0.5200
# Epoch 8/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6914 - accuracy: 0.5981 - val_loss: 0.6928 - val_accuracy: 0.5200
# Epoch 9/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6910 - accuracy: 0.6036 - val_loss: 0.6927 - val_accuracy: 0.5200
# Epoch 10/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6897 - accuracy: 0.6463 - val_loss: 0.6927 - val_accuracy: 0.5200
# Epoch 11/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.
100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6974 - accuracy: 0.4867 - val_loss: 0.6928 - val_accuracy: 0.5200
# Epoch 49/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6823 - accuracy: 0.5945 - val_loss: 0.6929 - val_accuracy: 0.5200
# Epoch 50/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6857 - accuracy: 0.5692 - val_loss: 0.6929 - val_accuracy: 0.5200
# Epoch 51/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6789 - accuracy: 0.6148 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 52/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6927 - accuracy: 0.5213 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 53/100
# 7/7 [==============================] - 0s 25ms/step - loss: 0.6744 - accuracy: 0.6422 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 54/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6719 - accuracy: 0.6562 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 55/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6742 - accuracy: 0.6393 - val_loss: 0.6932 - val_accuracy: 0.5200
# Epoch 56/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6935 - accuracy: 0.5179 - val_loss: 0.6932 - val_accuracy: 0.5200
# Epoch 57/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6827 - accuracy: 0.5846 - val_loss: 0.6933 - val_accuracy: 0.5200
# Epoch 58/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6705 - accuracy: 0.6578 - val_loss: 0.6933 - val_accuracy: 0.5200
# Epoch 59/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6808 - accuracy: 0.5940 - val_loss: 0.6934 - val_accuracy: 0.5200
# Epoch 60/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6782 - accuracy: 0.6088 - val_loss: 0.6934 - val_accuracy: 0.5200
# Epoch 61/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6769 - accuracy: 0.6153 - val_loss: 0.6935 - val_accuracy: 0.5200
# Epoch 62/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6705 - accuracy: 0.6502 - val_loss: 0.6936 - val_accuracy: 0.5200
# Epoch 63/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6645 - accuracy: 0.6823 - val_loss: 0.6936 - val_accuracy: 0.5200
# Epoch 64/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6754 - accuracy: 0.6203 - val_loss: 0.6937 - val_accuracy: 0.5200
# Epoch 65/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6854 - accuracy: 0.5651 - val_loss: 0.6937 - val_accuracy: 0.5200
# Epoch 66/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.6910 - accuracy: 0.5343 - val_loss: 0.6938 - val_accuracy: 0.5200
# Epoch 67/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6861 - accuracy: 0.5609 - val_loss: 0.6938 - val_accuracy: 0.5200
# Epoch 68/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6697 - accuracy: 0.6471 - val_loss: 0.6939 - val_accuracy: 0.5200
# Epoch 69/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6933 - accuracy: 0.5229 - val_loss: 0.6940 - val_accuracy: 0.5200
# Epoch 70/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6739 - accuracy: 0.6231 - val_loss: 0.6941 - val_accuracy: 0.5200
# Epoch 71/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6685 - accuracy: 0.6497 - val_loss: 0.6941 - val_accuracy: 0.5200
# Epoch 72/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.6759 - accuracy: 0.6114 - val_loss: 0.6942 - val_accuracy: 0.5200
# Epoch 73/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6679 - accuracy: 0.6502 - val_loss: 0.6943 - val_accuracy: 0.5200
# Epoch 74/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6754 - accuracy: 0.6122 - val_loss: 0.6943 - val_accuracy: 0.5200
# Epoch 75/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6769 - accuracy: 0.6041 - val_loss: 0.6944 - val_accuracy: 0.5200
# Epoch 76/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.6718 - accuracy: 0.6286 - val_loss: 0.6945 - val_accuracy: 0.5200
# Epoch 77/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6767 - accuracy: 0.6044 - val_loss: 0.6945 - val_accuracy: 0.5200
# Epoch 78/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6818 - accuracy: 0.5799 - val_loss: 0.6946 - val_accuracy: 0.5200
# Epoch 79/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6658 - accuracy: 0.6544 - val_loss: 0.6947 - val_accuracy: 0.5200
# Epoch 80/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.6848 - accuracy: 0.5656 - val_loss: 0.6947 - val_accuracy: 0.5200
# Epoch 81/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6804 - accuracy: 0.5856 - val_loss: 0.6948 - val_accuracy: 0.5200
# Epoch 82/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6864 - accuracy: 0.5580 - val_loss: 0.6949 - val_accuracy: 0.5200
# Epoch 83/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6879 - accuracy: 0.5513 - val_loss: 0.6949 - val_accuracy: 0.5200
# Epoch 84/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.6638 - accuracy: 0.6588 - val_loss: 0.6950 - val_accuracy: 0.5200
# Epoch 85/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6672 - accuracy: 0.6427 - val_loss: 0.6951 - val_accuracy: 0.5200
# Epoch 86/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6682 - accuracy: 0.6372 - val_loss: 0.6952 - val_accuracy: 0.5200
# Epoch 87/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6928 - accuracy: 0.5302 - val_loss: 0.6952 - val_accuracy: 0.5200
# Epoch 88/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.6724 - accuracy: 0.6182 - val_loss: 0.6953 - val_accuracy: 0.5200
# Epoch 89/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6789 - accuracy: 0.5901 - val_loss: 0.6954 - val_accuracy: 0.5200
# Epoch 90/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.6685 - accuracy: 0.6336 - val_loss: 0.6955 - val_accuracy: 0.5200
# Epoch 91/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6679 - accuracy: 0.6354 - val_loss: 0.6956 - val_accuracy: 0.5200
# Epoch 92/100
# 7/7 [==============================] - 0s 20ms/step - loss: 0.7092 - accuracy: 0.4635 - val_loss: 0.6956 - val_accuracy: 0.5200
# Epoch 93/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6677 - accuracy: 0.6351 - val_loss: 0.6957 - val_accuracy: 0.5200
# Epoch 94/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6614 - accuracy: 0.6601 - val_loss: 0.6958 - val_accuracy: 0.5200
# Epoch 95/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.6616 - accuracy: 0.6586 - val_loss: 0.6959 - val_accuracy: 0.5200
# Epoch 96/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6765 - accuracy: 0.5979 - val_loss: 0.6959 - val_accuracy: 0.5200
# Epoch 97/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6679 - accuracy: 0.6320 - val_loss: 0.6960 - val_accuracy: 0.5200
# Epoch 98/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6732 - accuracy: 0.6104 - val_loss: 0.6961 - val_accuracy: 0.5200
# Epoch 99/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.6541 - accuracy: 0.6856 - val_loss: 0.6962 - val_accuracy: 0.5200
# Epoch 100/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6897 - accuracy: 0.5453 - val_loss: 0.6962 - val_accuracy: 0.5200

# %%
y_pred = model.predict(X_test)
y_pred = y_pred > 0.5

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
a = accuracy_score(y_pred,y_test)
print('Accuracy is:', a*100)
# Out:
# Accuracy is: 52.0

# %%
sns.heatmap(confusion_matrix(y_pred, y_test), annot=True, fmt='g', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
# plt.xticks([i for i in range(25)])
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
# plt.xticks([i for i in range(25)])
plt.legend(['train', 'val'], loc='upper left')
plt.show()
